# %% [markdown]
# <a href="https://colab.research.google.com/github/ritulmishraa/Python-basics-Day1/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Print function in python**

# %%
# Python is a case sensitive language
print('Hello World')
# Out:
# Hello World

# %%
print('Ritul Mishra')
# Out:
# Ritul Mishra

# %%
print(7)
# Out:
# 7

# %%
print(7.7)
# Out:
# 7.7

# %%
print(True)
# Out:
# True

# %%
print('Hello',1,4.5,True)
# Out:
# Hello 1 4.5 True

# %%
print('Hello',1,4.5,True, sep = "/")
# Out:
# Hello/1/4.5/True

# %%
print('hello',end='-')
print('world')
# Out:
# hello-world

# %%
print('hello')
print('world')
# Out:
# hello
# world

# %% [markdown]
# Data Types

# %%
# Integer
print(8)
# 1*10^308
print(1e309)
# Out:
# 8
# inf

# %%
# Decimal/Float
print(8.55)
print(1.7e309)
# Out:
# 8.55
# inf

# %%
# Boolean
print(True)
print(False)
# Out:
# True
# False

# %%
# complex
print(5+6j)
# Out:
# (5+6j)

# %%
# List-> C-> Array
print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
# Tuple
print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
# Sets
print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
# Dictionary
print({'name':'Nitish','gender':'Male','weight':70})
# Out:
# {'name': 'Nitish', 'gender': 'Male', 'weight': 70}

# %% [markdown]
# Variables

# %%
# C/C++
name = 'Ritul'
print(name)

a = 5
b = 6

print(a + b)
# Out:
# Ritul
# 11

# %%
# Dynamic Typing
a = 5
# Static Typing
#int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'ritul'
print(a)

# Static Binding
#int a = 5
# Out:
# 5
# ritul

# %%
a = 1
b = 2
c = 3
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# Comments

# %%
# this is a comment
# second line
a = 4
b = 6 # like this
# second comment
print(a+b)
# Out:
# 10

# %% [markdown]
# Keywords and Identifiers

# %%
# Identifiers
# You can't start with a digit
name1 = 'Ritul'
print(name1)
# You can use special chars -> _
_ = 'Ritul'
print(_)
# identiers can not be keyword
# Out:
# Ritul
# Ritul

# %% [markdown]
# User Input

# %%
# Static Vs Dynamic
input('Enter Email')
# Out:
# Enter Emailritulm949@gmail.com
# 'ritulm949@gmail.com'

# %%
# take input from users and store them in a variable
fnum = int(input('enter first number'))
snum = int(input('enter second number'))
#print(type(fnum),type(snum))
# add the 2 variables
result = fnum + snum
# print the result
print(result)
print(type(fnum))
# Out:
# enter first number8
# enter second number3
# 11
# <class 'int'>

# %% [markdown]
# Type Conversion

# %%
# Implicit Vs Explicit
print(5+5.6)
print(type(5),type(5.6))

print(4 + '4')
# Out:
# 10.6
# <class 'int'> <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6511/3295153562.py in <cell line: 0>()
#       3 print(type(5),type(5.6))
#       4
# ----> 5 print(4 + '4')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# Explicit
# str -> int
#int(4+5j)

# int to str
str(5)

# float
float(4)
# Out:
# 4.0

# %% [markdown]
# Literals

# %%
a = 0b1010 #Binary Literals
b = 100 #Decimal Literal
c = 0o310 #Octal Literal
d = 0x12c #Hexadecimal Literal

#Float Literal
float_1 = 10.5
float_2 = 1.5e2 # 1.5 * 10^2
float_3 = 1.5e-3 # 1.5 * 10^-3

#Complex Literal
x = 3.14j

print(a, b, c, d)
print(float_1, float_2,float_3)
print(x, x.imag, x.real)
# Out:
# 10 100 200 300
# 10.5 150.0 0.0015
# 3.14j 3.14 0.0

# %%
string = 'This is Python'
strings = "This is Python"
char = "C"
multiline_str = """This is a multiline string with more than one line code."""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
# Out:
# This is Python
# This is Python
# C
# This is a multiline string with more than one line code.
# 😀😆🤣
# raw \n string

# %%
a = True + 4
b = False + 10

print("a:", a)
print("b:", b)
# Out:
# a: 5
# b: 10

# %%
k = None
a = 5
b = 6
print('Program exe')
# Out:
# Program exe

# %% [markdown]
# 8. Operators

# %%
# Arithmetic
# Relational
# Logical
# Bitwise
# Assignment
# Membership
